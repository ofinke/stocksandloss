# %%
# general imports
import pandas as pd
# imports stockandloss
import scraper as sc
import analyzer as an

# %%
# SCRAP RELEVANT INDEX
index = sc.scrap("QQQ")

# FIND CROSSES MA50 MA100
index.data = an.mov_average(index.data, 50)
index.data = an.mov_average(index.data, 100)

# CALCULATE CROSSES
index.data = an.find_crosses(index.data, col1="MA50", col2="MA100")
# Out:
#    _____
#   / ___/______________ _____  ___  _____
#   \__ \/ ___/ ___/ __ `/ __ \/ _ \/ ___/
#  ___/ / /__/ /  / /_/ / /_/ /  __/ /
# /____/\___/_/   \__,_/ .___/\___/_/
#                     /_/
#
# Version 0.1
#
# Scraping for stock(s) QQQ data.
#
# Scraping https://finance.yahoo.com/
# Status: started
# Status: scraping last 3 weeks
# Status: completed
# data saved as .dataweeks and .info
#
# Scraping completed

# %%
# SCRAP STOCK DATA
stock = sc.scrap("KBNT")

# insert crosses from the index
stock.data["gcross"] = index.data["gcross"]
stock.data["dcross"] = index.data["dcross"]
# Out:
#    _____
#   / ___/______________ _____  ___  _____
#   \__ \/ ___/ ___/ __ `/ __ \/ _ \/ ___/
#  ___/ / /__/ /  / /_/ / /_/ /  __/ /
# /____/\___/_/   \__,_/ .___/\___/_/
#                     /_/
#
# Version 0.1
#
# Scraping for stock(s) KBNT data.
#
# Scraping https://finance.yahoo.com/
# Status: started
# Status: scraping last 3 weeks
# Status: completed
# data saved as .dataweeks and .info
#
# Scraping completed

# %%
an.stock_plot(stock.data, stock.info)

# %%
stock.data
# Out:
#                       Datetime        Open        High         Low  \
# 0    2021-03-02 09:30:00-05:00  324.089996  324.160004  322.950012
# 1    2021-03-02 09:35:00-05:00  323.570007  323.570007  322.500000
# 2    2021-03-02 09:40:00-05:00  322.640015  322.809998  321.989990
# 3    2021-03-02 09:45:00-05:00  322.480011  322.769989  321.394012
# 4    2021-03-02 09:50:00-05:00  321.589996  322.100006  321.309998
# ...                        ...         ...         ...         ...
# 1165 2021-03-22 15:35:00-04:00  319.259796  319.404999  319.089996
# 1166 2021-03-22 15:40:00-04:00  319.200012  319.269989  318.890015
# 1167 2021-03-22 15:45:00-04:00  319.070007  319.179993  318.809998
# 1168 2021-03-22 15:50:00-04:00  319.029999  319.084991  318.609985
# 1169 2021-03-22 15:55:00-04:00  318.890015  318.920013  318.570007
#
#            Close   Volume        MA50       MA100  gcross  dcross
# 0     323.540009  2666213         NaN         NaN     0.0     0.0
# 1     322.649994   946672         NaN         NaN     0.0     0.0
# 2     322.476013   934067         NaN         NaN     0.0     0.0
# 3     321.600006  1136584         NaN         NaN     0.0     0.0
# 4     322.100006   970415         NaN         NaN     0.0     0.0
# ...          ...      ...         ...         ...     ...     ...
# 1165  319.209991   778073  319.959061  317.806261     0.0     0.0
# 1166  319.065002  1032259  319.958361  317.851411     0.0     0.0
# 1167  319.040009   756836  319.957181  317.899811     0.0     0.0
# 1168  318.890015  1708960  319.955581  317.946211     0.0     0.0
# 1169  318.679993  2062531  319.949181  317.995301     0.0     0.0
#
# [1170 rows x 10 columns]
