# %%
# imports
import market_status as ms
from IPython.display import display, Markdown, Javascript
import pandas as pd
import datetime as dt
import os
import time

# %% [markdown]
# ***
# # **Market Status Notebook**
# This notebook aims to provide comprehensive status of the market, which direction its heading and which sector is stronger than the other. All required code is written in python script ```market_status.py``` to save space. All days used in this notebook are meant as **trading** days.
#
# **Stuff to implement**
# - Options status for major indices
# - Distribution days for indices (based on the "How to Make Money in Stocks" book)
# - Add Nasdaq to indices overview (remove double stochastic, keep only VFI)
# - IPOs from last week (use finviz screener) with basic stats (IPO date, industry)
# - Crypto status (only the big ones compared to USD = BTC, ETH, další?)
# - Screener for sector performers
#
# ## **```World Markets```**

# %%
worldmarkets = ms.worldmarkets()
worldmarkets.show()

# %%
worldmarkets.performance()

# %% [markdown]
# ***
# ## **``American markets``**
# Spy = ETF following S&P500, IWM = ETF following Russell 2000

# %%
ms.show_usmarkets()

# %%
ms.longterm_usmarkets()

# %%
ms.momentum_usmarkets()
# Out:
# Last update done: 06-12-2021 at 13:57:43

# %% [markdown]
# ***
# ## **``Sectors``**
# Explanations:
# - Consumer Discretionary (cyclical) = goods and services that are considered non-essential by consumers, but desirable
# - Consumer Staples (non-cyclical, defensive) = set of essential products used by consumers. This category includes things like foods and beverages, household goods, and hygiene products as well as alcohol and tobacco.

# %%
sectors = ms.sectors()
sectors.show()

# %%
sectors.performance()

# %% [markdown]
# ***
# ## **`Futures`**
# Selected commodities futures.
# Will add also column for a relative year performance, but currently scrapper has a problem that the ethanol returns Null value.

# %%
futures = ms.futures()
futures.prettify(futures.returnfutures())
# Out:
# <style  type="text/css" >
# #T_c47e7_row0_col0,#T_c47e7_row0_col1,#T_c47e7_row0_col2,#T_c47e7_row0_col3,#T_c47e7_row1_col2,#T_c47e7_row1_col3,#T_c47e7_row2_col2,#T_c47e7_row2_col3,#T_c47e7_row3_col2,#T_c47e7_row3_col3,#T_c47e7_row4_col0,#T_c47e7_row4_col1,#T_c47e7_row4_col2,#T_c47e7_row4_col3,#T_c47e7_row5_col2,#T_c47e7_row5_col3,#T_c47e7_row6_col2,#T_c47e7_row6_col3,#T_c47e7_row7_col0,#T_c47e7_row7_col1,#T_c47e7_row7_col2,#T_c47e7_row7_col3,#T_c47e7_row8_col0,#T_c47e7_row8_col1,#T_c47e7_row8_col2,#T_c47e7_row8_col3,#T_c47e7_row9_col0,#T_c47e7_row10_col2,#T_c47e7_row11_col3,#T_c47e7_row12_col2,#T_c47e7_row12_col3,#T_c47e7_row15_col0,#T_c47e7_row15_col1,#T_c47e7_row16_col0,#T_c47e7_row16_col1,#T_c47e7_row17_col0,#T_c47e7_row17_col1,#T_c47e7_row17_col2,#T_c47e7_row19_col0,#T_c47e7_row19_col1,#T_c47e7_row19_col2,#T_c47e7_row19_col3,#T_c47e7_row20_col0,#T_c47e7_row20_col1,#T_c47e7_row20_col2,#T_c47e7_row20_col3,#T_c47e7_row21_col0,#T_c47e7_row21_col1,#T_c47e7_row21_col2,#T_c47e7_row21_col3,#T_c47e7_row22_col0,#T_c47e7_row22_col1{
#             color: red;
#         }#T_c47e7_row1_col0,#T_c47e7_row1_col1,#T_c47e7_row2_col0,#T_c47e7_row2_col1,#T_c47e7_row3_col0,#T_c47e7_row3_col1,#T_c47e7_row5_col0,#T_c47e7_row5_col1,#T_c47e7_row6_col0,#T_c47e7_row6_col1,#T_c47e7_row9_col1,#T_c47e7_row9_col2,#T_c47e7_row9_col3,#T_c47e7_row10_col0,#T_c47e7_row10_col1,#T_c47e7_row10_col3,#T_c47e7_row11_col0,#T_c47e7_row11_col1,#T_c47e7_row11_col2,#T_c47e7_row12_col0,#T_c47e7_row12_col1,#T_c47e7_row13_col0,#T_c47e7_row13_col1,#T_c47e7_row13_col2,#T_c47e7_row13_col3,#T_c47e7_row14_col0,#T_c47e7_row14_col1,#T_c47e7_row14_col2,#T_c47e7_row14_col3,#T_c47e7_row15_col2,#T_c47e7_row15_col3,#T_c47e7_row16_col2,#T_c47e7_row16_col3,#T_c47e7_row17_col3,#T_c47e7_row18_col0,#T_c47e7_row18_col1,#T_c47e7_row18_col2,#T_c47e7_row18_col3,#T_c47e7_row22_col2,#T_c47e7_row22_col3{
#             color: green;
#         }</style><table id="T_c47e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Day [%]</th>        <th class="col_heading level0 col1" >Week [%]</th>        <th class="col_heading level0 col2" >Month [%]</th>        <th class="col_heading level0 col3" >Quarter [%]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c47e7_level0_row0" class="row_heading level0 row0" >Natural Gas</th>
#                         <td id="T_c47e7_row0_col0" class="data row0 col0" >-8.52</td>
#                         <td id="T_c47e7_row0_col1" class="data row0 col1" >-8.52</td>
#                         <td id="T_c47e7_row0_col2" class="data row0 col2" >-31.47</td>
#                         <td id="T_c47e7_row0_col3" class="data row0 col3" >-19.78</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row1" class="row_heading level0 row1" >Crude Oil WTI</th>
#                         <td id="T_c47e7_row1_col0" class="data row1 col0" >3.09</td>
#                         <td id="T_c47e7_row1_col1" class="data row1 col1" >3.09</td>
#                         <td id="T_c47e7_row1_col2" class="data row1 col2" >-15.95</td>
#                         <td id="T_c47e7_row1_col3" class="data row1 col3" >-1.41</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row2" class="row_heading level0 row2" >Crude Oil Brent</th>
#                         <td id="T_c47e7_row2_col0" class="data row2 col0" >3.01</td>
#                         <td id="T_c47e7_row2_col1" class="data row2 col1" >3.01</td>
#                         <td id="T_c47e7_row2_col2" class="data row2 col2" >-13.00</td>
#                         <td id="T_c47e7_row2_col3" class="data row2 col3" >-0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row3" class="row_heading level0 row3" >Ethanol</th>
#                         <td id="T_c47e7_row3_col0" class="data row3 col0" >0.59</td>
#                         <td id="T_c47e7_row3_col1" class="data row3 col1" >0.59</td>
#                         <td id="T_c47e7_row3_col2" class="data row3 col2" >-10.48</td>
#                         <td id="T_c47e7_row3_col3" class="data row3 col3" >-4.72</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row4" class="row_heading level0 row4" >Palladium</th>
#                         <td id="T_c47e7_row4_col0" class="data row4 col0" >-2.52</td>
#                         <td id="T_c47e7_row4_col1" class="data row4 col1" >-2.52</td>
#                         <td id="T_c47e7_row4_col2" class="data row4 col2" >-12.85</td>
#                         <td id="T_c47e7_row4_col3" class="data row4 col3" >-26.87</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row5" class="row_heading level0 row5" >Copper</th>
#                         <td id="T_c47e7_row5_col0" class="data row5 col0" >0.80</td>
#                         <td id="T_c47e7_row5_col1" class="data row5 col1" >0.80</td>
#                         <td id="T_c47e7_row5_col2" class="data row5 col2" >-0.97</td>
#                         <td id="T_c47e7_row5_col3" class="data row5 col3" >-0.76</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row6" class="row_heading level0 row6" >Platinum</th>
#                         <td id="T_c47e7_row6_col0" class="data row6 col0" >0.49</td>
#                         <td id="T_c47e7_row6_col1" class="data row6 col1" >0.49</td>
#                         <td id="T_c47e7_row6_col2" class="data row6 col2" >-10.15</td>
#                         <td id="T_c47e7_row6_col3" class="data row6 col3" >-8.90</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row7" class="row_heading level0 row7" >Silver</th>
#                         <td id="T_c47e7_row7_col0" class="data row7 col0" >-0.56</td>
#                         <td id="T_c47e7_row7_col1" class="data row7 col1" >-0.56</td>
#                         <td id="T_c47e7_row7_col2" class="data row7 col2" >-7.46</td>
#                         <td id="T_c47e7_row7_col3" class="data row7 col3" >-9.87</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row8" class="row_heading level0 row8" >Gold</th>
#                         <td id="T_c47e7_row8_col0" class="data row8 col0" >-0.24</td>
#                         <td id="T_c47e7_row8_col1" class="data row8 col1" >-0.24</td>
#                         <td id="T_c47e7_row8_col2" class="data row8 col2" >-2.04</td>
#                         <td id="T_c47e7_row8_col3" class="data row8 col3" >-2.94</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row9" class="row_heading level0 row9" >Lumber</th>
#                         <td id="T_c47e7_row9_col0" class="data row9 col0" >-1.14</td>
#                         <td id="T_c47e7_row9_col1" class="data row9 col1" >18.00</td>
#                         <td id="T_c47e7_row9_col2" class="data row9 col2" >39.80</td>
#                         <td id="T_c47e7_row9_col3" class="data row9 col3" >41.44</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row10" class="row_heading level0 row10" >Cotton</th>
#                         <td id="T_c47e7_row10_col0" class="data row10 col0" >1.09</td>
#                         <td id="T_c47e7_row10_col1" class="data row10 col1" >1.09</td>
#                         <td id="T_c47e7_row10_col2" class="data row10 col2" >-9.87</td>
#                         <td id="T_c47e7_row10_col3" class="data row10 col3" >12.04</td>
#             </tr>
#             <tr>
#                         <th id="T_c47e7_level0_row11" class="row_heading level0 row11" >Cocoa</th>
#                         <td id="T_c47e7_row11_col0" class="data row11 col0" >0.57</td>
#                         <td id="T_c47e7_row11_col1" class="data row11 col1" >0.57</td>
#                         <td id="T_c47e7_row11_col2" class="data row11 col2" >1.35</td>
#                         <td id="T_c47e7_row11_col3" class="data row11 col3" >-6.52</td>
#             <

# %% [markdown]
# ***
# ## **`Crypto`**

# %%
# outptut table with cryptos and their preformance in last day/week/month

# %% [markdown]
# ***
# ## **``Finviz screeners``**
# Following tables are results from pre-defined finviz screeners
# <br><br>
# **New high Breakouts** - [[Link]](https://finviz.com/screener.ashx?v=211&s=ta_newhigh&f=ind_stocksonly,sh_avgvol_o100,sh_float_o5,sh_relvol_o1)
# <br>
# Stocks with new 52 week highs, with float over 5M shares, average volume 100k and relative volume over 1.

# %%
screeners = ms.screeners()
time.sleep(5)
nh = screeners.newhighs()
screeners.prettify(nh)
# Out:
# <style  type="text/css" >
# </style><table id="T_ba3ab_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba3ab_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ba3ab_row0_col0" class="data row0 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= MRVL " style="text-decoration: none"> MRVL </a></td>
#                         <td id="T_ba3ab_row0_col1" class="data row0 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= PLIN " style="text-decoration: none"> PLIN </a></td>
#                         <td id="T_ba3ab_row0_col2" class="data row0 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= SSD " style="text-decoration: none"> SSD </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ba3ab_row1_col0" class="data row1 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= LAND " style="text-decoration: none"> LAND </a></td>
#                         <td id="T_ba3ab_row1_col1" class="data row1 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= BXC " style="text-decoration: none"> BXC </a></td>
#                         <td id="T_ba3ab_row1_col2" class="data row1 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= ON " style="text-decoration: none"> ON </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ba3ab_row2_col0" class="data row2 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= PG " style="text-decoration: none"> PG </a></td>
#                         <td id="T_ba3ab_row2_col1" class="data row2 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= HPQ " style="text-decoration: none"> HPQ </a></td>
#                         <td id="T_ba3ab_row2_col2" class="data row2 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= TSEM " style="text-decoration: none"> TSEM </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ba3ab_row3_col0" class="data row3 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= MAS " style="text-decoration: none"> MAS </a></td>
#                         <td id="T_ba3ab_row3_col1" class="data row3 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= SHW " style="text-decoration: none"> SHW </a></td>
#                         <td id="T_ba3ab_row3_col2" class="data row3 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= BLDR " style="text-decoration: none"> BLDR </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ba3ab_row4_col0" class="data row4 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= SKY " style="text-decoration: none"> SKY </a></td>
#                         <td id="T_ba3ab_row4_col1" class="data row4 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= KEYS " style="text-decoration: none"> KEYS </a></td>
#                         <td id="T_ba3ab_row4_col2" class="data row4 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= EFX " style="text-decoration: none"> EFX </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ba3ab_row5_col0" class="data row5 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= DELL " style="text-decoration: none"> DELL </a></td>
#                         <td id="T_ba3ab_row5_col1" class="data row5 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= PLD " style="text-decoration: none"> PLD </a></td>
#                         <td id="T_ba3ab_row5_col2" class="data row5 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= TOL " style="text-decoration: none"> TOL </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ba3ab_row6_col0" class="data row6 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= SGH " style="text-decoration: none"> SGH </a></td>
#                         <td id="T_ba3ab_row6_col1" class="data row6 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= EIX " style="text-decoration: none"> EIX </a></td>
#                         <td id="T_ba3ab_row6_col2" class="data row6 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= MUSA " style="text-decoration: none"> MUSA </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ba3ab_row7_col0" class="data row7 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= LEN " style="text-decoration: none"> LEN </a></td>
#                         <td id="T_ba3ab_row7_col1" class="data row7 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= CLBK " style="text-decoration: none"> CLBK </a></td>
#                         <td id="T_ba3ab_row7_col2" class="data row7 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ba3ab_row8_col0" class="data row8 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#                         <td id="T_ba3ab_row8_col1" class="data row8 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#                         <td id="T_ba3ab_row8_col2" class="data row8 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#             </tr>
#             <tr>
#                         <th id="T_ba3ab_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ba3ab_row9_col0" class="data row9 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#                         <td id="T_ba3ab_row9_col1" class="data row9 col1" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#                         <td id="T_ba3ab_row9_col2" class="data row9 col2" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **50 day high with fundamentals** - [[Link]](https://finviz.com/screener.ashx?v=211&f=fa_debteq_u1,fa_eps5years_o10,fa_sales5years_o10,ind_stocksonly,sh_avgvol_o100,sh_float_o5,sh_relvol_o1,ta_highlow50d_nh)
# <br>
# Stocks which have 50 day highs with higher relative volume and basic fundamental filtration (dept/equity <1, sales and EPS growth in last 5 years larger than 10%)

# %%
time.sleep(5)
fd = screeners.fiftyday()
screeners.prettify(fd)
# Out:
# <style  type="text/css" >
# </style><table id="T_2e136_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e136_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2e136_row0_col0" class="data row0 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= SIMO " style="text-decoration: none"> SIMO </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2e136_row1_col0" class="data row1 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= AAON " style="text-decoration: none"> AAON </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2e136_row2_col0" class="data row2 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= CCS " style="text-decoration: none"> CCS </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2e136_row3_col0" class="data row3 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= DRNA " style="text-decoration: none"> DRNA </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2e136_row4_col0" class="data row4 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= ON " style="text-decoration: none"> ON </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2e136_row5_col0" class="data row5 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= KEYS " style="text-decoration: none"> KEYS </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2e136_row6_col0" class="data row6 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= LEN " style="text-decoration: none"> LEN </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2e136_row7_col0" class="data row7 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2e136_row8_col0" class="data row8 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#             </tr>
#             <tr>
#                         <th id="T_2e136_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2e136_row9_col0" class="data row9 col0" ><a target="_blank" href="https://finviz.com/quote.ashx?t= " style="text-decoration: none"> </a></td>
#             </tr>
#     </tbody></table>

# %%
# save the screener results into xlsx
with pd.ExcelWriter("Screeners/NH"+str(dt.date.today().strftime("%Y-%m"))+".xlsx", mode="a") as writer:
    nh.to_excel(writer, sheet_name=dt.date.today().strftime("%Y-%m-%d"))
with pd.ExcelWriter("Screeners/FD"+str(dt.date.today().strftime("%Y-%m"))+".xlsx", mode="a") as writer:
    fd.to_excel(writer, sheet_name=dt.date.today().strftime("%Y-%m-%d"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-62959fcb5c3d> in <module>
#       1 # save the screener results into xlsx
# ----> 2 with pd.ExcelWriter("Screeners/NH"+str(dt.date.today().strftime("%Y-%m"))+".xlsx", mode="a") as writer:
#       3     nh.to_excel(writer, sheet_name=dt.date.today().strftime("%Y-%m-%d"))
#       4 with pd.ExcelWriter("Screeners/FD"+str(dt.date.today().strftime("%Y-%m"))+".xlsx", mode="a") as writer:
#       5     fd.to_excel(writer, sheet_name=dt.date.today().strftime("%Y-%m-%d"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, **engine_kwargs)
#     178
#     179         if mode == "a":
# --> 180             raise ValueError("Append mode is not supported with xlsxwriter!")
#     181
#     182         super().__init__(
#
# ValueError: Append mode is not supported with xlsxwriter!

# %% [markdown]
# ***
# ## **`New IPOs`**
# New companies on the market during the last week, look for interesting price changes or so

# %% [markdown]
# ---
# ## **``Other resources``**
#
# List of other good resources to check (these will be hopefully implemented into this notebook later)
#
# 1. [Market momentum](https://www.barchart.com/stocks/momentum) - Watch for the number of stocks which are declining and advancing and overall number of new highs/new lows
# 2. [SPY p/c ratio](https://www.barchart.com/etfs-funds/quotes/SPY/put-call-ratios) - P/C ratio >1 = bearish

# %%
os.system("jupyter nbconvert --to html market_status.ipynb")

# %%
# output information about SPY and IWM options 
import yfinance as yf
import datetime as dt
import pandas as pd
import numpy as np

ticker = ["SPY", "IWM"]

# load ticker info
st = yf.Ticker(ticker[0])
# load options dates and calculate DTE (days to expiry)
today = dt.date.today()
dates = pd.DataFrame(data={"expiration":st.options})
dates["dte"] = [(today-dt.datetime.strptime(date,"%Y-%m-%d").date()) for date in dates["expiration"]]
dates["dte"] = np.abs(dates["dte"].dt.days)
# calculate options value for DTE <=10 and end of the next two months


c = st.option_chain(dates.loc[0, "expiration"]).calls["openInterest"].sum()
p = st.option_chain(dates.loc[0, "expiration"]).puts["openInterest"].sum()
cv = st.option_chain(dates.loc[0, "expiration"]).calls["volume"].sum()
pv = st.option_chain(dates.loc[0, "expiration"]).calls["volume"].sum()
print(ticker[0] + ": expiration " + dates.loc[0, "expiration"] + ", OI P/C ratio: " + str(np.round(p/c, 2)) + ", Volume P/C ratio: " + str(np.round(pv/cv, 2)))


# Other market factors: Put/Calls, New high/New low, decliners/advancers, % of stocks above SMA50
