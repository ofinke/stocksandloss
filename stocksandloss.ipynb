# %%
# IMPORTS
import scraper as sc
import analyzer as an

# DEFINITION OF REQUIRED DATA
# stock handle, all caps, without $, currently only one at a time is allowed
stockHandle = "TSLA"
# number of days, all data are loaded from today to - number of specified days

# %%
stock = sc.scrap(stockHandle)
# Out:
#    _____
#   / ___/______________ _____  ___  _____
#   \__ \/ ___/ ___/ __ `/ __ \/ _ \/ ___/
#  ___/ / /__/ /  / /_/ / /_/ /  __/ /
# /____/\___/_/   \__,_/ .___/\___/_/
#                     /_/
#
# Version 0.1
#
# Scraping for stock(s): TSLA
#
# Scraping https://finance.yahoo.com/
# Status: started
# Status: scraping last 7 days
# Status: scraping last 1 month
# Status: scraping last 3 months
# Status: scraping last year
# Status: completed
# data saved as .datadays, .datayear, and .info
#
# Scraping completed

# %%
an.year_plot(stock.datayear, stock.info)
